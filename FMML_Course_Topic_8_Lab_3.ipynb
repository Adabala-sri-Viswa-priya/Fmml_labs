# %% [markdown]
# <a href="https://colab.research.google.com/github/Adabala-sri-Viswa-priya/Fmml_labs/blob/main/Copy_of_FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 14:50:06--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  57.3MB/s    in 1.2s
#
# 2024-03-31 14:50:12 (57.3 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 5243    1203.5181v1  We describe $k$-MLE, a fast and efficient loca...    cs
# 26493  1610.08481v2  A head-mounted display (HMD) could be an impor...    cs
# 20729  1611.08219v3  It is clear that one of the primary tools we c...    cs
# 2461   1502.03919v2  Several authors have recently developed risk-s...    cs
# 24653   1410.0969v1  Recently, many approaches have been introduced...    cs
# ...             ...                                                ...   ...
# 19071   1304.0806v3  In this work, we present definition of intuiti...    cs
# 32572   1312.7381v2  A rekindled the interest in auto-encoder algor...    cs
# 14670   0908.4431v1  OLAC was founded in 2000 for creating online d...    cs
# 18806   1204.3255v2  One of the big challenges in the development o...    cs
# 23009  1801.09367v1  The vanishing ideal is a set of polynomials th...  stat
#
#                                                    title  year  \
# 5243   $k$-MLE: A fast algorithm for learning statist...  2012
# 26493  Mask-off: Synthesizing Face Images in the Pres...  2016
# 20729                                The Off-Switch Game  2016
# 2461          Policy Gradient for Coherent Risk Measures  2015
# 24653  A Model of Plant Identification System Using G...  2014
# ...                                                  ...   ...
# 19071  IFP-Intuitionistic fuzzy soft set theory and i...  2013
# 32572                      Rate-Distortion Auto-Encoders  2013
# 14670          An OLAC Extension for Dravidian Languages  2009
# 18806       Lower Complexity Bounds for Lifted Inference  2012
# 23009      Approximate Vanishing Ideal via Data Knotting  2018
#
#                                                 keywords
# 5243   [efficient, algorithm, statistical, exponentia...
# 26493  [important, component, augmented, seriously, e...
# 20729  [potential, misbehaving, capabilities, importa...
# 2461   [developed, sensitive, minimization, variabili...
# 24653  [approaches, introduced, researchers, applicat...
# ...                                                  ...
# 19071  [definition, intuitionistic, parameterized, in...
# 32572  [rekindled, algorithms, effective, architectur...
# 14670  [databases, resources, distributed, character,...
# 18806  [challenges, development, probabilistic, relat...
# 23009  [vanishing, polynomials, originally, vanishing...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 5243     [efficient, algorithm, statistical, exponentia...
# 26493    [important, component, augmented, seriously, e...
# 20729    [potential, misbehaving, capabilities, importa...
# 2461     [developed, sensitive, minimization, variabili...
# 24653    [approaches, introduced, researchers, applicat...
#                                ...
# 1030     [identification, inferring, artificial, simult...
# 10369    [financial, providing, forecasting, automatic,...
# 1790     [dirichlet, extension, stochastic, processes, ...
# 11923    [adversarial, including, demonstrated, vulnera...
# 22998    [motivations, variational, inference, signific...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8886 words.
# Out of those 4568 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1a320b1d-854d-4b77-b98b-5e7d657b869a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a320b1d-854d-4b77-b98b-5e7d657b869a")) {                    Plotly.newPlot(                        "1a320b1d-854d-4b77-b98b-5e7d657b869a",                        [{"x":["criterion","algorithm","initialize","prescribed","component","iteratively","celebrated","parameter","maximization","estimators","efficient","clustering","implemented","interpreted","likelihood","hartigans","successively","minimizing","incomplete","guaranteeing","additively","expectation","divergences","heuristic","initialization","probabilistically","traditionally","performed","monotonically","processes","technique","statistical","proportion","increases","convergence","exponential","synthesize","sequences","telecommunication","applications","personalized","framework","colorization","movements","seriously","variations","occlusions","important","experimental","realistic","alignment","reconstruction","synthesis","synthesizing","augmented","experience","traditional","uncertain","generalization","objectives","potential","uncertainty","challenge","appropriate","capabilities","observations","incentives","objective","incentive","classical","preservation","associated","perfectly","switching","formulations","importantly","generalizes","reinforcement","variability","contribution","sensitive","programming","approximation","algorithms","minimization","consistent","conditional","operations","developed","identification","comparison","therefore","possibilities","practices","researchers","conducted","combination","performance","approaches","introduced","classifier","experiments","occurrence","outperforms","subsystem","observable","different","estimating","desirable","representation","reductions","variables","markovian","structural","parsimonious","existence","parametric","theoretic","complications","complexity","reduction","conditions","operation","effectively","treatment","counterexample","endogenous","significant","exogenous","semantics","relations","equivalent","reparametrizations","marginalization","describes","amplifying","benchmarks","significantly","modifying","stereotypes","evaluation","geometrically","demonstrate","embedding","resulting","properties","definition","maintaining","association","disturbing","receptionist","debiasing","processing","embeddings","widespread","represent","methodology","preserving","application","programmer","associations","empirically","direction","separable","ultrametric","intrinsically","statistic","irregularly","implement","elongated","dimensional","combining","guarantees","correctly","introduce","mislabeled","multiscale","adjacency","informative","robustness","determines","estimation","underlying","artificial","mechanisms","influence","restrictions","identifies","interpretability","relationships","considered","regarding","linearity","developing","generation","applicability","predictors","prediction","structure","implementation"],"y":[46,819,5,6,97,27,5,129,39,16,377,139,98,30,61,2,5,56,23,3,3,26,8,47,30,4,32,123,11,110,244,175,7,58,120,48,10,89,2,423,17,533,9,15,5,54,21,345,391,67,62,109,39,14,36,37,150,39,105,23,151,89,140,76,51,82,2,170,5,91,4,129,12,15,18,27,37,128,24,71,55,114,117,624,70,90,97,67,205,91,138,147,19,12,74,82,136,911,409,136,137,596,24,250,4,20,761,69,32,334,13,130,3,72,3,35,39,38,6,217,105,137,35,112,30,1,2,228,4,95,105,54,0,3,74,1,93,261,11,2,258,6,552,109,137,228,34,39,40,2,2,2,286,80,15,120,62,57,257,3,22,73,79,16,1,8,4,1,47,1,189,114,70,33,329,1,10,4,39,91,13,215,110,128,47,54,13,18,20,75,134,41,5,77,148,41,12,244,355,123],"type":"bar"},{"x":["criterion","algorithm","initialize","prescribed","component","iteratively","cele ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4568,), (4568, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7933333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Frank</span> <span style=''>Wolfe</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Symmetric</span> <span style=''>NMF</span> <span style=''>under</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Simplicial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Constraint</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>Frank</span> <span style=''>Wolfe</span> <span style=''>(FW)</span> <span style=''>solver</span> <span style=''>to</span> <span style=''>optimize</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>symmetric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>nonnegative</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3953488372093023);'>factorization</span> <span style=''>problem</span> <span style=''>under</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>simplicial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraint</span> <span style=''>Compared</span> <span style=''>with</span> <span style=''>existing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>solutions</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extremely</span> <span style=''>simple</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implement</span> <span style=''>and</span> <span style=''>has</span> <span style=''>almost</span> <span style=''>no</span> <span style='background-color:rgba(255, 0, 0, 0.4468085106382979);'>hyperparameters</span> <span style=''>to</span> <span style=''>be</span> <span style=''>tuned</span> <span style=''>Building</span> <span style=''>on</span> <span style=''>the</span> <span style=''>recent</span> <span style=''>advances</span> <span style=''>of</span> <span style=''>FW</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.38461538461538475);'>nonconvex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>we</span> <span style=''>prove</span> <span style=''>an</span> <span style=''>O(1varepsilon2)</span> <span style='background-color:rgba(255, 0, 0, 0.32584269662921345);'>convergence</span> <span style=''>rate</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3580246913580247);'>stationary</span> <span style=''>points</span> <span style=''>via</span> <span style=''>a</span> <span style=''>tight</span> <span style=''>bound</span> <span style=''>Theta(n2)</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>curvature</span> <span style=''>constant</span> <span style='background-color:rgba(255, 0, 0, 0.39350180505415167);'>Numerical</span> <span style=''>results</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3556231003039513);'>effectiveness</span> <span style=''>of</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>As</span> <span style=''>a</span> <span style=''>side</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>contribution</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>construct</span> <span style=''>a</span> <span style=''>simple</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333334);'>nonsmooth</span> <span style=''>convex</span> <span style=''>problem</span> <span style=''>where</span> <span style=''>the</span> <span style=''>FW</span> <span styl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>perturbation</span> <span style=''>and</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sparsification</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>completion</span> <br/><br/><span style=''>We</span> <span style=''>discuss</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>perturbation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inequalities</span> <span style=''>when</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>perturbation</span> <span style=''>is</span> <span style=''>random</span> <span style=''>As</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>we</span> <span style=''>obtain</span> <span style=''>several</span> <span style=''>new</span> <span style=''>results</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>concerning</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>problems</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sparsification</span> <span style=''>and</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>completion</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Escaping</span> <span style=''>From</span> <span style=''>Saddle</span> <span style=''>Points</span> <span style=''>Online</span> <span style='background-color:rgba(255, 0, 0, 0.31428571428571433);'>Stochastic</span> <span style=''>Gradient</span> <span style=''>for</span> <span style=''>Tensor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Decomposition</span> <br/><br/><span style=''>We</span> <span style=''>analyze</span> <span style='background-color:rgba(255, 0, 0, 0.31428571428571433);'>stochastic</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3076923076923077);'>optimizing</span> <span style=''>non</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>In</span> <span style=''>many</span> <span style=''>cases</span> <span style=''>for</span> <span style=''>non</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>the</span> <span style=''>goal</span> <span style=''>is</span> <span style=''>to</span> <span style=''>find</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reasonable</span> <span style=''>local</span> <span style=''>minimum</span> <span style=''>and</span> <span style=''>the</span> <span style=''>main</span> <span style=''>concern</span> <span style=''>is</span> <span style=''>that</span> <span style=''>gradient</span> <span style=''>updates</span> <span style=''>are</span> <span style=''>trapped</span> <span style=''>in</span> <span style=''>saddle</span> <span style=''>points</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>identify</span> <span style=''>strict</span> <span style=''>saddle</span> <span style=''>property</span> <span style=''>for</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>problem</span> <span style=''>that</span> <span style=''>allows</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>Using</span> <span style=''>this</span> <span style=''>property</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.31428571428571433);'>stochastic</span> <span style=''>gradient</span> <span style=''>descent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>converges</span> <span style=''>to</span> <span style=''>a</span> <span style=''>local</span> <span style=''>minimum</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iterations</span> <span style=''>To</span> <span style=''>the</span> <span style=''>best</span> <span style=''>of</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3964757709251102);'>knowledge</span> <span style=''>this</span> <span style=''>is</span> <span style=''>the</span> <span style=''>first</span> <span style=''>work</span> <span style=''>that</span> <span style=''>gives</span> <span style=''>global</span> <span style='background-color:rgba(255, 0, 0, 0.32584269662921345);'>convergence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantees</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.31428571428571433);'>stochastic</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>on</span> <span style=''>non</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0,  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Multi</span> <span style=''>view</span> <span style=''>Learning</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonparametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonlinear</span> <span style=''>Inter</span> <span style=''>Battery</span> <span style=''>Factor</span> <span style=''>Analysis</span> <br/><br/><span style=''>Factor</span> <span style=''>analysis</span> <span style=''>aims</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>determine</span> <span style=''>latent</span> <span style=''>factors</span> <span style=''>or</span> <span style=''>traits</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>summarize</span> <span style=''>a</span> <span style=''>given</span> <span style=''>data</span> <span style=''>set</span> <span style=''>Inter</span> <span style=''>battery</span> <span style=''>factor</span> <span style=''>analysis</span> <span style=''>extends</span> <span style=''>this</span> <span style=''>notion</span> <span style=''>to</span> <span style=''>multiple</span> <span style=''>views</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>show</span> <span style=''>how</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style=''>version</span> <span style=''>of</span> <span style=''>these</span> <span style=''>models</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recovered</span> <span style=''>through</span> <span style=''>the</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>latent</span> <span style=''>variable</span> <span style=''>model</span> <span style=''>This</span> <span style=''>gives</span> <span style=''>us</span> <span style=''>a</span> <span style=''>flexible</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formalism</span> <span style=''>for</span> <span style=''>multi</span> <span style=''>view</span> <span style=''>learning</span> <span style=''>where</span> <span style=''>the</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>both</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploratory</span> <span style=''>purposes</span> <span style=''>and</span> <span style=''>for</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>that</span> <span style=''>enable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>ambiguous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>tasks</span> <span style=''>Learning</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performed</span> <span style=''>in</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style=''>manner</span> <span style=''>through</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulation</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>compression</span> <span style=''>scheme</span> <span style=''>which</span> <span style=''>gives</span> <span style=''>a</span> <span style=''>rigorous</span> <span style=''> ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.09152181624689606)
# 	processing (0.10145441645973749)
# 	experimental (0.13870166725789287)
# 	architecture (0.08939340191557289)
# 	segmentation (0.0716566158212132)
# 	information (0.24086555516140476)
# 	convolutional (0.12273855977296914)
# 	recognition (0.11777225966654842)
# 	different (0.26995388435615464)
# 	detection (0.12380276693863072)
#
# Some Statistics words are:
# 	stochastic (0.12771327612317013)
# 	statistical (0.15648662291771834)
# 	theoretical (0.15295305401312467)
# 	variables (0.14285714285714285)
# 	algorithm (0.38869257950530034)
# 	estimation (0.17768803634528016)
# 	distribution (0.18828874305906107)
# 	dimensional (0.19636547198384655)
# 	inference (0.20646138313982837)
# 	regression (0.18879353861686018)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fc279e4e-6b97-48bf-b403-007b58124386" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fc279e4e-6b97-48bf-b403-007b58124386")) {                    Plotly.newPlot(                        "fc279e4e-6b97-48bf-b403-007b58124386",                        [{"x":["criterion","algorithm","initialize","prescribed","component","iteratively","celebrated","parameter","maximization","estimators","efficient","clustering","implemented","interpreted","likelihood","hartigans","successively","minimizing","incomplete","guaranteeing","additively","expectation","divergences","heuristic","initialization","probabilistically","traditionally","performed","monotonically","processes","technique","statistical","proportion","increases","convergence","exponential","synthesize","sequences","telecommunication","applications","personalized","framework","colorization","movements","seriously","variations","occlusions","important","experimental","realistic","alignment","reconstruction","synthesis","synthesizing","augmented","experience","traditional","uncertain","generalization","objectives","potential","uncertainty","challenge","appropriate","capabilities","observations","incentives","objective","incentive","classical","preservation","associated","perfectly","switching","formulations","importantly","generalizes","reinforcement","variability","contribution","sensitive","programming","approximation","algorithms","minimization","consistent","conditional","operations","developed","identification","comparison","therefore","possibilities","practices","researchers","conducted","combination","performance","approaches","introduced","classifier","experiments","occurrence","outperforms","subsystem","observable","different","estimating","desirable","representation","reductions","variables","markovian","structural","parsimonious","existence","parametric","theoretic","complications","complexity","reduction","conditions","operation","effectively","treatment","counterexample","endogenous","significant","exogenous","semantics","relations","equivalent","reparametrizations","marginalization","describes","amplifying","benchmarks","significantly","modifying","stereotypes","evaluation","geometrically","demonstrate","embedding","resulting","properties","definition","maintaining","association","disturbing","receptionist","debiasing","processing","embeddings","widespread","represent","methodology","preserving","application","programmer","associations","empirically","direction","separable","ultrametric","intrinsically","statistic","irregularly","implement","elongated","dimensional","combining","guarantees","correctly","introduce","mislabeled","multiscale","adjacency","informative","robustness","determines","estimation","underlying","artificial","mechanisms","influence","restrictions","identifies","interpretability","relationships","considered","regarding","linearity","developing","generation","applicability","predictors","prediction","structure","implementation","mechanism","intervention","parameters","meaningful","evaluated","demonstrated","necessary","estimates","interventional","cerebellar","reasonable","adaptation","according","furthermore","computation","presented","forgetting","assumptions","dependent","irrelevant","recognition","understood","analytically","significance","establish","subspaces","corresponding","theoretical","projection","observation","unsupervised","phenomenon","expressed","potentially","expressive","improvement","substantial","additional","projecting","projected","fundamental","parametrization","determined","quadratic","functions","validation","regression","characterized","principle","supervised","competitive","covariance","selection","tractable","procedur ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	reparametrizations
# 	governing
# 	replicates
# 	factorisation
# 	unraveling
# 	automates
# 	overparameterized
# 	contractive
# 	faithfulness
# 	interrelated
# 	projectorg
# 	subsampled
# 	distributedly
# 	ulcerative
# 	tessellation
# 	isometrically
# 	monitored
# 	practitioner
# 	emphdirectly
# 	frequentist
# Some words which never appear in Statistics papers:
# 	colorization
# 	seriously
# 	occlusions
# 	incentive
# 	stereotypes
# 	receptionist
# 	programmer
# 	cerebellar
# 	grounding
# 	reciprocity
# 	localizing
# 	referring
# 	interdisciplinary
# 	undistortion
# 	authoring
# 	researches
# 	uniformity
# 	traveling
# 	formidable
# 	apparently

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0526894193784724e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7508333333333334
